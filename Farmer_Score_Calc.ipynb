# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/CreditScoreData - Sheet1.csv" , parse_dates= True)

# %%
df
# Out:
#      User     Date   I/E
# 0       1   1/2/23  -732
# 1       1   1/2/23 -1881
# 2       1   2/2/23  -114
# 3       1   2/2/23 -1602
# 4       1   3/2/23   142
# ..    ...      ...   ...
# 117     1  29/3/23   998
# 118     1  30/3/23   332
# 119     1  30/3/23 -1919
# 120     1  31/3/23  1425
# 121     1  31/3/23 -2128
#
# [122 rows x 3 columns]

# %%
daily_income = df.groupby('Date' , sort = False)['I/E'].sum().reset_index()


daily_income['daily_status'] = daily_income['I/E'].apply(lambda x: 1 if x > 0 else -1)

df_new = pd.DataFrame(daily_income)

# %%
df_new
# Out:
#        Date   I/E  daily_status
# 0    1/2/23 -2613            -1
# 1    2/2/23 -1716            -1
# 2    3/2/23  1358             1
# 3    4/2/23 -1220            -1
# 4    5/2/23   101             1
# ..      ...   ...           ...
# 56  27/3/23  -426            -1
# 57  28/3/23  -684            -1
# 58  29/3/23  2395             1
# 59  30/3/23 -1587            -1
# 60  31/3/23  -703            -1
#
# [61 rows x 3 columns]

# %%
weekly_sum = df_new['daily_status'].rolling(window=7).sum()
weekly_mode = weekly_sum.apply(lambda x: -1 if x < 0 else 1)

# %%
df_new['weekly_mode'] = weekly_mode

# %%
df_new
# Out:
#        Date   I/E  daily_status  weekly_mode
# 0    1/2/23 -2613            -1            1
# 1    2/2/23 -1716            -1            1
# 2    3/2/23  1358             1            1
# 3    4/2/23 -1220            -1            1
# 4    5/2/23   101             1            1
# ..      ...   ...           ...          ...
# 56  27/3/23  -426            -1           -1
# 57  28/3/23  -684            -1           -1
# 58  29/3/23  2395             1           -1
# 59  30/3/23 -1587            -1           -1
# 60  31/3/23  -703            -1           -1
#
# [61 rows x 4 columns]

# %%
weekly_sum = df_new['weekly_mode'].rolling(window=7).sum()

# %%
def calculate_score(weekly_modes):
      score = 250
      consecutive_count = 0
      for mode in weekly_modes:
        if mode == 1:
            score += 1
            consecutive_count = max(0, consecutive_count + 1)
        elif mode == -1:
            score -= 1
            consecutive_count = max(0, consecutive_count + 1)
        else:
            consecutive_count = 0

        if consecutive_count == 3:
            if mode == 1:
                score += 5
            elif mode == -1:
                score -= 5

      return score

# %%
cf_sc  = calculate_score(df_new['weekly_mode'])

# %%
print(cf_sc)
# Out:
# 242
